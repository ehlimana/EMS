# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime

# %%
scope_traces=[] #this will be the list of dataframes
file_names=os.listdir('Measurement data')

# %% [markdown]
# Provjera upload-a:

# %%
file_names[0]
# Out:
# '01012016.xls'

# %% [markdown]
# Odabir kolona iz Excel sheetova za svaki fajl:

# %%
column_indices1=list(range(2))
column_indices2=list((np.arange(1,3)))
column_indices3=list((np.arange(1,6)))
columns_from_sheets={'Plinomjer istočna zgra 00039413':column_indices1,'Brojilo el.energije su 35649294':column_indices2,"Brojilo el.energije tr 35649314":column_indices2,'Vodomjer stara 09249850':[1],'Vodomjer nova 09249847':[1],'Vodomjer hidrant 10058705':[1],'Brojilo el.energije ko 46621646':column_indices2,
'Brojilo el.energije po 38878959':column_indices2,'Brojilo el.energije kl 46868995':column_indices2,'Kalorimetar 1 39024788':column_indices3,
 'Kalorimetar 2 39024724':column_indices3,'Kalorimetar 3 39024787':column_indices3,'Temp.senzor un.1 24003403':column_indices2,'Temp.senzor un.2 24004659':column_indices2,
 'Temp.senzor un.3 24003393':column_indices2,'Temp.senzor un.4 24004658':column_indices2,'Temp.senzor un.5 24007590':column_indices2,'Temp.senzor un.6 24007412':column_indices2,'Temp.senzor un.7 24007548':column_indices2,'Temp.senzor un.8 24007403':column_indices2, 'Temp.senzor vanj.1 25000099':column_indices2,'Plinomjer zapadna zgra 20526379':[1]   }

# %% [markdown]
# Preuzimanje podataka iz svakog sheet-a i spajanje u jedan sheet za svaki dan pojedinačno. Iz odabira je isključen sheet 'Brojilo el.energije Lo 46622131', jer je prazan. Sheetovi imaju različite nazive kroz fajlove, pa se moraju staviti u petlju. Ovaj korak malo duže traje prilikom izvršavanja.

# %%
df_all_files=[None]*len(file_names)

column_indices=list(columns_from_sheets.values())
for file in file_names:
    xls=pd.ExcelFile('Measurement data\\'+file)
    sheet_names=xls.sheet_names
    delete_names=['Brojilo el.energije Lo 46622131',]
    selected_sheet_names=[ele for ele in sheet_names if ele not in delete_names]
    
    df=[None]*len(selected_sheet_names)
    df=[pd.read_excel('Measurement data\\'+file, sheet_name=i, usecols=column_indices[selected_sheet_names.index(i)],ignore_index=True) for i in selected_sheet_names]
    df1=pd.concat(df[:],axis=1)
    df_all_files[file_names.index(file)]=df1

# %% [markdown]
# Provjera da li postoje podaci za svaki dan u opsegu 00:00 do 23:00. Na osnovu toga su određeni listovi (kolona: Datum i vrijeme) popunjeni satima koji nedostaju, a vrijednosti podataka su prazne ćelije.

# %%
def check_empty(trace,i):
    empty_cell=(trace['Datum i vrijeme'].isnull().values.any())
    if empty_cell==True:
        print("Empty_cell",i)
    else:
        pass

# %%
for i in range(len(df_all_files)): #check for all files
    print(i, end="\r") 
    check_empty(df_all_files[i],i)
# Out:
# 630

# %%
df_all_files[32]
# Out:
#         Datum i vrijeme  Plin (m3)  El.energija VT (kWh)  \
# 0   02.04.2017 00:00:00        NaN                   NaN
# 1   02.04.2017 01:00:00        NaN                   NaN
# 2   02.04.2017 02:00:00        NaN                   NaN
# 3   02.04.2017 03:00:00        NaN                   NaN
# 4   02.04.2017 04:00:00        NaN                   NaN
# 5   02.04.2017 05:00:00        NaN                   NaN
# 6   02.04.2017 06:00:00        NaN                   NaN
# 7   02.04.2017 07:00:00        NaN                   NaN
# 8   02.04.2017 08:00:00        NaN                   NaN
# 9   02.04.2017 09:00:00  1475060.0              468609.4
# 10  02.04.2017 10:00:00  1475060.0              468609.4
# 11  02.04.2017 11:00:00  1475060.0              468609.4
# 12  02.04.2017 12:00:00  1475060.0              468609.4
# 13  02.04.2017 13:00:00  1475060.0              468609.4
# 14  02.04.2017 14:00:00  1475060.0              468609.4
# 15  02.04.2017 15:00:00  1475060.0              468609.4
# 16  02.04.2017 16:00:00  1475060.0              468609.4
# 17  02.04.2017 17:00:00  1475060.0              468609.4
# 18  02.04.2017 18:00:00  1475060.0              468609.4
# 19  02.04.2017 19:00:00  1475060.0              468609.4
# 20  02.04.2017 20:00:00  1475060.0              468609.4
# 21  02.04.2017 21:00:00  1475060.0              468609.4
# 22  02.04.2017 22:00:00  1475060.0              468609.4
# 23  02.04.2017 23:00:00  1475060.0              468609.4
#
#     El.energija MT (kWh)  El.energija VT (kWh)  El.energija MT (kWh)  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9              309542.28             1531195.0             1417410.2
# 10             309548.08             1531195.0             1417446.8
# 11             309553.88             1531195.0             1417484.0
# 12             309559.56             1531195.0             1417521.4
# 13             309564.80             1531195.0             1417559.0
# 14             309570.20             1531195.0             1417597.4
# 15             309575.44             1531195.0             1417636.8
# 16             309580.44             1531195.0             1417676.4
# 17             309585.48             1531195.0             1417715.6
# 18             309590.52             1531195.0             1417754.8
# 19             309595.96             1531195.0             1417793.6
# 20             309602.12             1531195.0             1417832.2
# 21             309608.28             1531195.0             1417871.0
# 22             309614.84             1531195.0             1417908.8
# 23             309621.64             1531195.0             1417946.6
#
#     Voda (m3)  Voda (m3)  Voda (m3)  El.energija VT (kWh)  ...  Vlažnost (%)  \
# 0         NaN   18635.84       12.3                   NaN  ...           NaN
# 1         NaN   18635.86       12.3                   NaN  ...           NaN
# 2         NaN   18635.90       12.3                   NaN  ...           NaN
# 3         NaN   18635.94       12.3                   NaN  ...           NaN
# 4         NaN   18636.02       12.3                   NaN  ...           NaN
# 5         NaN   18636.10       12.3                   NaN  ...           NaN
# 6         NaN   18636.18       12.3                   NaN  ...           NaN
# 7         NaN   18636.26       12.3                   NaN  ...           NaN
# 8         NaN   18636.36       12.3                   NaN  ...           NaN
# 9    13994.48   18636.47       12.3               67287.0  ...         27.46
# 10   13994.62   18636.62       12.3               67287.0  ...         24.09
# 11   13994.79   18636.76       12.3               67287.0  ...         23.66
# 12   13994.93   18636.89       12.3               67287.0  ...         22.52
# 13   13995.08   18637.04       12.3               67287.0  ...         22.57
# 14   13995.23   18637.17       12.3               67287.0  ...         22.09
# 15   13995.40   18637.31       12.3               67287.0  ...         22.96
# 16   13995.54   18637.45       12.3               67287.0  ...         23.66
# 17   13995.67   18637.59       12.3               67287.0  ...         24.37
# 18   13995.81   18637.72       12.3               67287.0  ...         22.16
# 19   13995.94   18637.86       12.3               67287.0  ...         23.88
# 20   13996.06   18637.99       12.3               67287.0  ...         27.92
# 21   13996.18   18638.09       12.3               67287.0  ...         28.99
# 22   13996.28   18638.17       12.3               67287.0  ...         29.54
# 23   13996.38   18638.24       12.3               67287.0  ...         30.22
#
#     Temperatura (°C)  Vlažnost (%)  Temperatura (°C)  Vlažnost (%)  \
# 0                NaN           NaN               NaN           NaN
# 1                NaN           NaN               NaN           NaN
# 2                NaN           NaN               NaN           NaN
# 3                NaN           NaN               NaN           NaN
# 4                NaN           NaN               NaN           NaN
# 5                NaN           NaN               NaN           NaN
# 6                NaN           NaN               NaN           NaN
# 7                NaN           NaN               NaN           NaN
# 8                NaN           NaN             24.72         27.02
# 9              22.56         31.14             25.70         26.15
# 10             22.68         30.91             26.36         25.40
# 11             22.76         30.91             26.81         25.36
# 12             22.83         30.88             27.09         25.17
# 13             22.91         30.86             27.14         25.24
# 14             22.97         30.83             26.97         25.52
# 15             23.03         30.80             26.59         26.04
# 16             22.98         30.79             26.04         26.61
# 17             22.92         30.89             25.64         26.98
# 18             22.90         30.93             25.36         27.10
# 19             22.74         31.09             25.10         27.34
# 20             22.65         31.12             24.89         26.89
# 21             22.59         31.22             24.75         26.81
# 22             22.52         31.17             24.60         26.90
# 23             22.47         31.21             24.48         27.04
#
#     Temperatura (°C)  Vlažnost (%)  Temperatura (°C)  Vlažnost (%)  Plin (m3)
# 0                NaN           NaN               NaN           NaN        NaN
# 1                NaN           NaN               NaN           NaN        NaN
# 2                NaN           NaN               NaN           NaN        NaN
# 3                NaN           NaN               NaN           NaN        NaN
# 4                NaN           NaN               NaN           NaN        NaN
# 5                NaN           NaN               NaN           NaN        NaN
# 6                NaN           NaN               NaN           NaN        NaN
# 7                NaN           NaN               NaN           NaN        NaN
# 8              24.11         29.12             12.38         53.26        NaN
# 9              24.29         29.66             16.42         44.69   103490.0
# 10             24.13         29.72             17.91         38.85   103490.0
# 11             23.99         28.61             19.13         33.38   103490.0
# 12             23.98         27.47             20.72         31.41   103490.0
# 13             24.02         27.47             21.98         28.66   103490.0
# 14             24.06         27.40             23.45         28.57   103490.0
# 15             24.08         27.97             23.29         27.13   103490.0
# 16             24.03         28.47             22.24         28.44   103490.0
# 17             23.97         28.18             21.49         29.61   103490.0
# 18             23.86         28.17             20.59         31.33   103490.0
# 19             23.76         28.02             19.12         37.46   103490.0
# 20             23.64         27.73             17.37         47.94   103490.0
# 21             23.57         28.08             15.85         50.95   103490.0
# 22             23.49         28.43             14.64         53.06   103490.0
# 23             23.41         28.67             13.62         56.53   103490.0
#
# [24 rows x 49 columns]

# %% [markdown]
# Spajanje dnevnih podataka u jedan veliki fajl za sve 3 godine:

# %%
df_total=pd.concat(df_all_files[:],axis=0, ignore_index=True)
df_total.tail()
# Out:
#            Datum i vrijeme  Plin (m3)  El.energija VT (kWh)  \
# 15122  31.12.2017 19:00:00  1509294.0             481853.36
# 15123  31.12.2017 20:00:00  1509294.0             481853.36
# 15124  31.12.2017 21:00:00  1509294.0             481853.36
# 15125  31.12.2017 22:00:00  1509294.0             481853.36
# 15126  31.12.2017 23:00:00  1509294.0             481853.36
#
#       El.energija MT (kWh)  El.energija VT (kWh) El.energija MT (kWh)  \
# 15122            365280.80                   NaN                  NaN
# 15123            365289.96                   NaN                  NaN
# 15124            365299.24                   NaN                  NaN
# 15125            365308.56                   NaN                  NaN
# 15126            365318.28                   NaN                  NaN
#
#       Voda (m3) Voda (m3) Voda (m3)  El.energija VT (kWh)  ...  Vlažnost (%)  \
# 15122     15278       NaN       NaN               67287.0  ...         28.43
# 15123     15278       NaN       NaN               67287.0  ...         28.74
# 15124     15278       NaN       NaN               67287.0  ...         28.98
# 15125     15278       NaN       NaN               67287.0  ...         29.11
# 15126     15278       NaN       NaN               67287.0  ...         29.17
#
#        Temperatura (°C)  Vlažnost (%)  Temperatura (°C)  Vlažnost (%)  \
# 15122             19.84         31.16             21.32         27.76
# 15123             19.77         31.22             21.16         27.89
# 15124             19.71         31.25             21.01         28.02
# 15125             19.62         31.28             20.89         28.08
# 15126             19.56         31.27             20.80         28.15
#
#        Temperatura (°C)  Vlažnost (%)  Temperatura (°C)  Vlažnost (%)  \
# 15122             18.97         34.80              1.74         84.61
# 15123             18.86         34.79              1.37         85.76
# 15124             18.75         34.78              0.97         87.14
# 15125             18.65         34.77              0.50         87.71
# 15126             18.53         34.69              0.34         88.09
#
#        Plin (m3)
# 15122   114606.0
# 15123   114606.0
# 15124   114606.0
# 15125   114606.0
# 15126   114606.0
#
# [5 rows x 49 columns]

# %% [markdown]
# Radi sortiranja po datumu, kreira se kolona "DATUM" koja koristi kolonu "Datum i vrijeme" da bi se izdvojio samo datum iz podataka.

# %%
df_total['DATUM'] = df_total["Datum i vrijeme"].apply(pd.to_datetime)

# %% [markdown]
# Pregled:

# %%
df_total
# Out:
#            Datum i vrijeme  Plin (m3)  El.energija VT (kWh)  \
# 0      01.01.2016 00:00:00  3034444.0             393783.96
# 1      01.01.2016 01:00:00  3034444.0             393784.92
# 2      01.01.2016 02:00:00  3034444.0             393784.92
# 3      01.01.2016 03:00:00  3034444.0             393784.92
# 4      01.01.2016 04:00:00  3034444.0             393784.92
# ...                    ...        ...                   ...
# 15122  31.12.2017 19:00:00  1509294.0             481853.36
# 15123  31.12.2017 20:00:00  1509294.0             481853.36
# 15124  31.12.2017 21:00:00  1509294.0             481853.36
# 15125  31.12.2017 22:00:00  1509294.0             481853.36
# 15126  31.12.2017 23:00:00  1509294.0             481853.36
#
#       El.energija MT (kWh)  El.energija VT (kWh) El.energija MT (kWh)  \
# 0                241848.80           1.27791e+06          1.17775e+06
# 1                241861.52           1.27791e+06          1.17779e+06
# 2                241874.96           1.27791e+06          1.17783e+06
# 3                241888.52           1.27791e+06          1.17788e+06
# 4                241902.04           1.27791e+06          1.17793e+06
# ...                    ...                   ...                  ...
# 15122            365280.80                   NaN                  NaN
# 15123            365289.96                   NaN                  NaN
# 15124            365299.24                   NaN                  NaN
# 15125            365308.56                   NaN                  NaN
# 15126            365318.28                   NaN                  NaN
#
#       Voda (m3) Voda (m3) Voda (m3)  El.energija VT (kWh)  ...  \
# 0           NaN       NaN       NaN               67287.0  ...
# 1           NaN       NaN       NaN               67287.0  ...
# 2           NaN       NaN       NaN               67287.0  ...
# 3           NaN       NaN       NaN               67287.0  ...
# 4           NaN       NaN       NaN               67287.0  ...
# ...         ...       ...       ...                   ...  ...
# 15122     15278       NaN       NaN               67287.0  ...
# 15123     15278       NaN       NaN               67287.0  ...
# 15124     15278       NaN       NaN               67287.0  ...
# 15125     15278       NaN       NaN               67287.0  ...
# 15126     15278       NaN       NaN               67287.0  ...
#
#        Temperatura (°C)  Vlažnost (%)  Temperatura (°C)  Vlažnost (%)  \
# 0                 18.21         31.64             18.68         27.84
# 1                 18.12         31.63             18.54         27.72
# 2                 18.02         31.56             18.42         27.57
# 3                 17.91         31.51             18.31         27.42
# 4                 17.82         31.47             18.19         27.38
# ...                 ...           ...               ...           ...
# 15122             19.84         31.16             21.32         27.76
# 15123             19.77         31.22             21.16         27.89
# 15124             19.71         31.25             21.01         28.02
# 15125             19.62         31.28             20.89         28.08
# 15126             19.56         31.27             20.80         28.15
#
#        Temperatura (°C)  Vlažnost (%)  Temperatura (°C)  Vlažnost (%)  \
# 0                 17.21         26.95             -2.82         62.20
# 1                 17.00         26.93             -3.21         63.84
# 2                 16.83         26.99             -4.09         66.08
# 3                 16.65         27.05             -4.33         72.30
# 4                 16.47         27.03             -4.91         68.61
# ...                 ...           ...               ...           ...
# 15122             18.97         34.80              1.74         84.61
# 15123             18.86         34.79              1.37         85.76
# 15124             18.75         34.78              0.97         87.14
# 15125             18.65         34.77              0.50         87.71
# 15126             18.53         34.69              0.34         88.09
#
#        Plin (m3)               DATUM
# 0        95196.0 2016-01-01 00:00:00
# 1        95196.0 2016-01-01 01:00:00
# 2        95196.0 2016-01-01 02:00:00
# 3        95196.0 2016-01-01 03:00:00
# 4        95196.0 2016-01-01 04:00:00
# ...          ...                 ...
# 15122   114606.0 2017-12-31 19:00:00
# 15123   114606.0 2017-12-31 20:00:00
# 15124   114606.0 2017-12-31 21:00:00
# 15125   114606.0 2017-12-31 22:00:00
# 15126   114606.0 2017-12-31 23:00:00
#
# [15127 rows x 50 columns]

# %% [markdown]
# Promjena naziva kolona prema sheetovima iz kojih dolaze. Ovo je bilo neophodno jer se npr. kolona *Temperatura* i *Vlažnost* ponavljaju kroz sheet-ove pa da se zna odakle koja dolazi.

# %%
new_names=[selected_sheet_names[0],selected_sheet_names[0],selected_sheet_names[1],selected_sheet_names[1],selected_sheet_names[2],selected_sheet_names[2],
selected_sheet_names[3],selected_sheet_names[4],selected_sheet_names[5],selected_sheet_names[6],selected_sheet_names[6],selected_sheet_names[7],
selected_sheet_names[7],selected_sheet_names[8],selected_sheet_names[8],selected_sheet_names[9],
selected_sheet_names[9],selected_sheet_names[9],selected_sheet_names[9],selected_sheet_names[9],selected_sheet_names[10],
selected_sheet_names[10],selected_sheet_names[10],selected_sheet_names[10],selected_sheet_names[10],
selected_sheet_names[11],selected_sheet_names[11],selected_sheet_names[11],selected_sheet_names[11],selected_sheet_names[11],
selected_sheet_names[12],selected_sheet_names[12],selected_sheet_names[13],selected_sheet_names[13],
selected_sheet_names[11],selected_sheet_names[11],selected_sheet_names[12],selected_sheet_names[12],
selected_sheet_names[14],selected_sheet_names[14],selected_sheet_names[15],selected_sheet_names[15],
selected_sheet_names[16],selected_sheet_names[16],selected_sheet_names[17],selected_sheet_names[17],
selected_sheet_names[18],selected_sheet_names[18],selected_sheet_names[19], ""]

# %%
df_total=df_total.set_axis(list(df_total.columns+' '+new_names), axis='columns', inplace=False)

# %%
df_total.head()
# Out:
#   Datum i vrijeme Plinomjer ist.zgrada 00062313  \
# 0                           01.01.2016 00:00:00
# 1                           01.01.2016 01:00:00
# 2                           01.01.2016 02:00:00
# 3                           01.01.2016 03:00:00
# 4                           01.01.2016 04:00:00
#
#    Plin (m3) Plinomjer ist.zgrada 00062313  \
# 0                                3034444.0
# 1                                3034444.0
# 2                                3034444.0
# 3                                3034444.0
# 4                                3034444.0
#
#    El.energija VT (kWh) Brojilo el.energije su 35649294  \
# 0                                          393783.96
# 1                                          393784.92
# 2                                          393784.92
# 3                                          393784.92
# 4                                          393784.92
#
#    El.energija MT (kWh) Brojilo el.energije su 35649294  \
# 0                                          241848.80
# 1                                          241861.52
# 2                                          241874.96
# 3                                          241888.52
# 4                                          241902.04
#
#   El.energija VT (kWh) Brojilo el.energije tr 35649314  \
# 0                                        1.27791e+06
# 1                                        1.27791e+06
# 2                                        1.27791e+06
# 3                                        1.27791e+06
# 4                                        1.27791e+06
#
#   El.energija MT (kWh) Brojilo el.energije tr 35649314  \
# 0                                        1.17775e+06
# 1                                        1.17779e+06
# 2                                        1.17783e+06
# 3                                        1.17788e+06
# 4                                        1.17793e+06
#
#   Voda (m3) Vodomjer stara 09249850 Voda (m3) Vodomjer nova 09249847  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   Voda (m3) Vodomjer hidrant 10058705  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    El.energija VT (kWh) Brojilo el.energije ko 46621646  ...  \
# 0                                            67287.0     ...
# 1                                            67287.0     ...
# 2                                            67287.0     ...
# 3                                            67287.0     ...
# 4                                            67287.0     ...
#
#    Temperatura (°C) Temp.senzor un.4 24004658  \
# 0                                       18.21
# 1                                       18.12
# 2                                       18.02
# 3                                       17.91
# 4                                       17.82
#
#    Vlažnost (%) Temp.senzor un.4 24004658  \
# 0                                   31.64
# 1                                   31.63
# 2                                   31.56
# 3                                   31.51
# 4                                   31.47
#
#    Temperatura (°C) Temp.senzor un.5 24007590  \
# 0                                       18.68
# 1                                       18.54
# 2                                       18.42
# 3                                       18.31
# 4                                       18.19
#
#   Vlažnost (%) Temp.senzor un.5 24007590  \
# 0                                  27.84
# 1                                  27.72
# 2                                  27.57
# 3                                  27.42
# 4                                  27.38
#
#   Temperatura (°C) Temp.senzor un.6 24007412  \
# 0                                      17.21
# 1                                      17.00
# 2                                      16.83
# 3                                      16.65
# 4                                      16.47
#
#    Vlažnost (%) Temp.senzor un.6 24007412  \
# 0                                   26.95
# 1                                   26.93
# 2                                   26.99
# 3                                   27.05
# 4                                   27.03
#
#    Temperatura (°C) Temp.senzor un.7 24007548  \
# 0                                       -2.82
# 1                                       -3.21
# 2                                       -4.09
# 3                                       -4.33
# 4                                       -4.91
#
#    Vlažnost (%) Temp.senzor un.7 24007548  \
# 0                                   62.20
# 1                                   63.84
# 2                                   66.08
# 3                                   72.30
# 4                                   68.61
#
#    Plin (m3) Temp.senzor un.8 24007403              DATUM
# 0                              95196.0 2016-01-01 00:00:00
# 1                              95196.0 2016-01-01 01:00:00
# 2                              95196.0 2016-01-01 02:00:00
# 3                              95196.0 2016-01-01 03:00:00
# 4                              95196.0 2016-01-01 04:00:00
#
# [5 rows x 50 columns]

# %% [markdown]
# Sortiranje po datumu:

# %%
df_total=df_total.sort_values(by="DATUM ")

# %%
df_total.head()
# Out:
#     Datum i vrijeme Plinomjer ist.zgrada 00062313  \
# 312                           01.10.2015 00:00:00
# 313                           01.10.2015 01:00:00
# 314                           01.10.2015 02:00:00
# 315                           01.10.2015 03:00:00
# 316                           01.10.2015 04:00:00
#
#      Plin (m3) Plinomjer ist.zgrada 00062313  \
# 312                                3009985.0
# 313                                3009985.0
# 314                                3009985.0
# 315                                3009985.0
# 316                                3009985.0
#
#      El.energija VT (kWh) Brojilo el.energije su 35649294  \
# 312                                          371651.16
# 313                                          371651.16
# 314                                          371651.16
# 315                                          371651.16
# 316                                          371651.16
#
#      El.energija MT (kWh) Brojilo el.energije su 35649294  \
# 312                                          230421.12
# 313                                          230427.44
# 314                                          230433.52
# 315                                          230440.12
# 316                                          230446.64
#
#     El.energija VT (kWh) Brojilo el.energije tr 35649314  \
# 312                                        1.22569e+06
# 313                                        1.22569e+06
# 314                                        1.22569e+06
# 315                                        1.22569e+06
# 316                                        1.22569e+06
#
#     El.energija MT (kWh) Brojilo el.energije tr 35649314  \
# 312                                        1.13019e+06
# 313                                        1.13022e+06
# 314                                        1.13026e+06
# 315                                        1.13029e+06
# 316                                        1.13032e+06
#
#     Voda (m3) Vodomjer stara 09249850 Voda (m3) Vodomjer nova 09249847  \
# 312                               NaN                              NaN
# 313                               NaN                              NaN
# 314                               NaN                              NaN
# 315                               NaN                              NaN
# 316                               NaN                              NaN
#
#     Voda (m3) Vodomjer hidrant 10058705  \
# 312                                 NaN
# 313                                 NaN
# 314                                 NaN
# 315                                 NaN
# 316                                 NaN
#
#      El.energija VT (kWh) Brojilo el.energije ko 46621646  ...  \
# 312                                            67287.0     ...
# 313                                            67287.0     ...
# 314                                            67287.0     ...
# 315                                            67287.0     ...
# 316                                            67287.0     ...
#
#      Temperatura (°C) Temp.senzor un.4 24004658  \
# 312                                       21.74
# 313                                       21.68
# 314                                       21.64
# 315                                       21.60
# 316                                       21.58
#
#      Vlažnost (%) Temp.senzor un.4 24004658  \
# 312                                   42.62
# 313                                   42.55
# 314                                   42.48
# 315                                   42.51
# 316                                   42.47
#
#      Temperatura (°C) Temp.senzor un.5 24007590  \
# 312                                       22.26
# 313                                       22.22
# 314                                       22.17
# 315                                       22.12
# 316                                       22.07
#
#     Vlažnost (%) Temp.senzor un.5 24007590  \
# 312                                  38.66
# 313                                  38.66
# 314                                  38.72
# 315                                  38.78
# 316                                  38.91
#
#     Temperatura (°C) Temp.senzor un.6 24007412  \
# 312                                      21.06
# 313                                      20.98
# 314                                      20.92
# 315                                      20.84
# 316                                      20.79
#
#      Vlažnost (%) Temp.senzor un.6 24007412  \
# 312                                   44.52
# 313                                   44.38
# 314                                   44.31
# 315                                   44.23
# 316                                   44.19
#
#      Temperatura (°C) Temp.senzor un.7 24007548  \
# 312                                       11.14
# 313                                       11.12
# 314                                       10.88
# 315                                       10.86
# 316                                       10.80
#
#      Vlažnost (%) Temp.senzor un.7 24007548  \
# 312                                   80.24
# 313                                   79.87
# 314                                   83.93
# 315                                   83.88
# 316                                   85.09
#
#      Plin (m3) Temp.senzor un.8 24007403              DATUM
# 312                              85344.0 2015-01-10 00:00:00
# 313                              85344.0 2015-01-10 01:00:00
# 314                              85344.0 2015-01-10 02:00:00
# 315                              85344.0 2015-01-10 03:00:00
# 316                              85344.0 2015-01-10 04:00:00
#
# [5 rows x 50 columns]

# %% [markdown]
# Spašavanje fajla:

# %%
df_total.to_excel("Merged files.xlsx", index=False)
